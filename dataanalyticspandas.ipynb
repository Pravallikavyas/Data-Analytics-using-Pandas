# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravallikavyas/Data-Analytics-using-Pandas/blob/main/dataanalyticspandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing libraries and loading dataframe**

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Pandas - Q1 Sales.csv",header=8)

# %%
df
# Out:
#         India   West    Bill   4/16/2017 0:00:00    240000   200
# 0          US   West  Thomas   7/13/2012 0:00:00  26000000  1000
# 1          UK  North    John   5/20/2015 0:00:00    100000  1000
# 2   Australia  North    Bill    7/5/2018 0:00:00    120000   567
# 3      Africa  North  Thomas   7/18/2017 0:00:00    140000  1000
# 4   Singapore   East    John   5/16/2014 0:00:00    160000   892
# 5     Mylasia   East    Bill   4/16/2012 0:00:00    180000   444
# 6       India   East  Thomas   8/16/2012 0:00:00    200000    90
# 7          US   West    John  11/30/2011 0:00:00    220000    90
# 8          UK   West    Bill  10/11/2015 0:00:00    240000    90
# 9   Australia   West  Thomas  10/23/2017 0:00:00    260000    90
# 10     Africa  North    John   12/7/2013 0:00:00    140000    85
# 11  Singapore  North    Bill   9/22/2010 0:00:00    150000    85

# %%
df=pd.read_csv("/content/Pandas - Q1 Sales.csv")

# %%
df
# Out:
#       Country Region Sales Person    Date of Purchase     Total  Quantity
# 0       India  North         John   7/25/2013 0:00:00    100000       567
# 1          US  North         Bill   11/3/2014 0:00:00    120000      3000
# 2          UK  North       Thomas    1/3/2011 0:00:00    140000       345
# 3   Australia   East         John    8/6/2018 0:00:00    160000      1000
# 4      Africa   East         Bill   7/27/2015 0:00:00    180000       123
# 5   Singapore   East       Thomas    7/3/2014 0:00:00    200000      1000
# 6     Mylasia   West         John   8/17/2012 0:00:00   1000000      7890
# 7       India   West         Bill   4/16/2017 0:00:00    240000       200
# 8          US   West       Thomas   7/13/2012 0:00:00  26000000      1000
# 9          UK  North         John   5/20/2015 0:00:00    100000      1000
# 10  Australia  North         Bill    7/5/2018 0:00:00    120000       567
# 11     Africa  North       Thomas   7/18/2017 0:00:00    140000      1000
# ...

# %% [markdown]
# **Pandas Dataframe basics functions**

# %%
df.head( )
# Out:
#      Country Region Sales Person   Date of Purchase   Total  Quantity
# 0      India  North         John  7/25/2013 0:00:00  100000       567
# 1         US  North         Bill  11/3/2014 0:00:00  120000      3000
# 2         UK  North       Thomas   1/3/2011 0:00:00  140000       345
# 3  Australia   East         John   8/6/2018 0:00:00  160000      1000
# 4     Africa   East         Bill  7/27/2015 0:00:00  180000       123

# %%
df.head(10)
# Out:
#      Country Region Sales Person   Date of Purchase     Total  Quantity
# 0      India  North         John  7/25/2013 0:00:00    100000       567
# 1         US  North         Bill  11/3/2014 0:00:00    120000      3000
# 2         UK  North       Thomas   1/3/2011 0:00:00    140000       345
# 3  Australia   East         John   8/6/2018 0:00:00    160000      1000
# 4     Africa   East         Bill  7/27/2015 0:00:00    180000       123
# 5  Singapore   East       Thomas   7/3/2014 0:00:00    200000      1000
# 6    Mylasia   West         John  8/17/2012 0:00:00   1000000      7890
# 7      India   West         Bill  4/16/2017 0:00:00    240000       200
# 8         US   West       Thomas  7/13/2012 0:00:00  26000000      1000
# 9         UK  North         John  5/20/2015 0:00:00    100000      1000

# %%
df.tail()
# Out:
#       Country Region Sales Person    Date of Purchase   Total  Quantity
# 15         US   West         John  11/30/2011 0:00:00  220000        90
# 16         UK   West         Bill  10/11/2015 0:00:00  240000        90
# 17  Australia   West       Thomas  10/23/2017 0:00:00  260000        90
# 18     Africa  North         John   12/7/2013 0:00:00  140000        85
# 19  Singapore  North         Bill   9/22/2010 0:00:00  150000        85

# %%
df.tail(10)
# Out:
#       Country Region Sales Person    Date of Purchase   Total  Quantity
# 10  Australia  North         Bill    7/5/2018 0:00:00  120000       567
# 11     Africa  North       Thomas   7/18/2017 0:00:00  140000      1000
# 12  Singapore   East         John   5/16/2014 0:00:00  160000       892
# 13    Mylasia   East         Bill   4/16/2012 0:00:00  180000       444
# 14      India   East       Thomas   8/16/2012 0:00:00  200000        90
# 15         US   West         John  11/30/2011 0:00:00  220000        90
# 16         UK   West         Bill  10/11/2015 0:00:00  240000        90
# 17  Australia   West       Thomas  10/23/2017 0:00:00  260000        90
# 18     Africa  North         John   12/7/2013 0:00:00  140000        85
# 19  Singapore  North         Bill   9/22/2010 0:00:00  150000        85

# %%
df.shape
# Out:
# (20, 6)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Sales Person', 'Date of Purchase', 'Total',
#        'Quantity'],
#       dtype='object')

# %%
df.describe( )
# Out:
#               Total     Quantity
# count  2.000000e+01    20.000000
# mean   1.502500e+06   977.900000
# std    5.769280e+06  1761.923497
# min    1.000000e+05    85.000000
# 25%    1.400000e+05    90.000000
# 50%    1.700000e+05   505.500000
# 75%    2.250000e+05  1000.000000
# max    2.600000e+07  7890.000000

# %% [markdown]
# **Inserting rows and columns in dataframe**

# %%
df["Country"]
# Out:
# 0         India
# 1            US
# 2            UK
# 3     Australia
# 4        Africa
# 5     Singapore
# 6       Mylasia
# 7         India
# 8            US
# 9            UK
# 10    Australia
# 11       Africa
# 12    Singapore
# 13      Mylasia
# 14        India
# 15           US
# 16           UK
# 17    Australia
# 18       Africa
# 19    Singapore
# Name: Country, dtype: object

# %%
selected_lists=["Country","Sales Person","Quantity"]

# %%
df[selected_lists]
# Out:
#       Country Sales Person  Quantity
# 0       India         John       567
# 1          US         Bill      3000
# 2          UK       Thomas       345
# 3   Australia         John      1000
# 4      Africa         Bill       123
# 5   Singapore       Thomas      1000
# 6     Mylasia         John      7890
# 7       India         Bill       200
# 8          US       Thomas      1000
# 9          UK         John      1000
# 10  Australia         Bill       567
# 11     Africa       Thomas      1000
# 12  Singapore         John       892
# 13    Mylasia         Bill       444
# 14      India       Thomas        90
# 15         US         John        90
# 16         UK         Bill        90
# 17  Australia       Thomas        90
# 18     Africa         John        85
# 19  Singapore         Bill        85

# %%
df[(df["Country"]=="India") & (df["Quantity"]>90)]
# Out:
#   Country Region Sales Person   Date of Purchase   Total  Quantity
# 0   India  North         John  7/25/2013 0:00:00  100000       567
# 7   India   West         Bill  4/16/2017 0:00:00  240000       200

# %%
calls_made=[10]*10+[60]*10

# %%
df["CallsMade"]=calls_made

# %%
df
# Out:
#       Country Region Sales Person    Date of Purchase     Total  Quantity  \
# 0       India  North         John   7/25/2013 0:00:00    100000       567
# 1          US  North         Bill   11/3/2014 0:00:00    120000      3000
# 2          UK  North       Thomas    1/3/2011 0:00:00    140000       345
# 3   Australia   East         John    8/6/2018 0:00:00    160000      1000
# 4      Africa   East         Bill   7/27/2015 0:00:00    180000       123
# 5   Singapore   East       Thomas    7/3/2014 0:00:00    200000      1000
# 6     Mylasia   West         John   8/17/2012 0:00:00   1000000      7890
# 7       India   West         Bill   4/16/2017 0:00:00    240000       200
# 8          US   West       Thomas   7/13/2012 0:00:00  26000000      1000
# 9          UK  North         John   5/20/2015 0:00:00    100000      1000
# 10  Australia  North         Bill    7/5/2018 0:00:00    120000       567
# 11     Africa  North       Thomas   7/18/2017 0:00:00    140000      1000
# ...

# %%
row=["India","South","San","12/7/2013 0:00:00",'2000','90','60']

# %%
new_df_row=pd.DataFrame([row],columns=df.columns.values)

# %%
df.append(new_df_row)
# Out:
# <ipython-input-23-98d589246af8>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_df_row)
#       Country Region Sales Person    Date of Purchase     Total Quantity  \
# 0       India  North         John   7/25/2013 0:00:00    100000      567
# 1          US  North         Bill   11/3/2014 0:00:00    120000     3000
# 2          UK  North       Thomas    1/3/2011 0:00:00    140000      345
# 3   Australia   East         John    8/6/2018 0:00:00    160000     1000
# 4      Africa   East         Bill   7/27/2015 0:00:00    180000      123
# 5   Singapore   East       Thomas    7/3/2014 0:00:00    200000     1000
# 6     Mylasia   West         John   8/17/2012 0:00:00   1000000     7890
# 7       India   West         Bill   4/16/2017 0:00:00    240000      200
# 8          US   West       Thomas   7/13/2012 0:00:00  26000000     1000
# ...

# %%
df.iloc[1:5]
# Out:
#      Country Region Sales Person   Date of Purchase   Total  Quantity  \
# 1         US  North         Bill  11/3/2014 0:00:00  120000      3000
# 2         UK  North       Thomas   1/3/2011 0:00:00  140000       345
# 3  Australia   East         John   8/6/2018 0:00:00  160000      1000
# 4     Africa   East         Bill  7/27/2015 0:00:00  180000       123
#
#    CallsMade
# 1         10
# 2         10
# 3         10
# 4         10

# %%
df.loc[10:12]
# Out:
#       Country Region Sales Person   Date of Purchase   Total  Quantity  \
# 10  Australia  North         Bill   7/5/2018 0:00:00  120000       567
# 11     Africa  North       Thomas  7/18/2017 0:00:00  140000      1000
# 12  Singapore   East         John  5/16/2014 0:00:00  160000       892
#
#     CallsMade
# 10         60
# 11         60
# 12         60

# %% [markdown]
# **Sorting Dataframes (by value and by index)**

# %%
po_numbers=[int(f"1000{i}") for i in range(20)]
import random
random.shuffle(po_numbers)

# %%
df["POnumbers"]=po_numbers

# %%
df.set_index("POnumbers",inplace=True)

# %%
df.sort_index(ascending=True)
# Out:
#              Country Region Sales Person    Date of Purchase     Total  \
# POnumbers
# 10000         Africa   East         Bill   7/27/2015 0:00:00    180000
# 10001          India   East       Thomas   8/16/2012 0:00:00    200000
# 10002          India   West         Bill   4/16/2017 0:00:00    240000
# 10003             US  North         Bill   11/3/2014 0:00:00    120000
# 10004      Australia  North         Bill    7/5/2018 0:00:00    120000
# 10005      Australia   West       Thomas  10/23/2017 0:00:00    260000
# 10006         Africa  North         John   12/7/2013 0:00:00    140000
# 10007      Singapore   East       Thomas    7/3/2014 0:00:00    200000
# 10008             US   West       Thomas   7/13/2012 0:00:00  26000000
# 10009             US   West         John  11/30/2011 0:00:00    220000
# 100010            UK  North         John   5/20/2015 0:00:00    100000
# 100011     Singapore   East         John   5/16/2014 0:00:00    160000
# ...

# %%
df.sort_values(["Sales Person","Region"],ascending=False,inplace=True)

# %%
df
# Out:
#              Country Region Sales Person    Date of Purchase     Total  \
# POnumbers
# 10008             US   West       Thomas   7/13/2012 0:00:00  26000000
# 10005      Australia   West       Thomas  10/23/2017 0:00:00    260000
# 100019            UK  North       Thomas    1/3/2011 0:00:00    140000
# 100017        Africa  North       Thomas   7/18/2017 0:00:00    140000
# 10007      Singapore   East       Thomas    7/3/2014 0:00:00    200000
# 10001          India   East       Thomas   8/16/2012 0:00:00    200000
# 100013       Mylasia   West         John   8/17/2012 0:00:00   1000000
# 10009             US   West         John  11/30/2011 0:00:00    220000
# 100012         India  North         John   7/25/2013 0:00:00    100000
# 100010            UK  North         John   5/20/2015 0:00:00    100000
# 10006         Africa  North         John   12/7/2013 0:00:00    140000
# 100015     Australia   East         John    8/6/2018 0:00:00    160000
# ...

# %%
df.sort_values(["Total","Region"],inplace=True)

# %%
df
# Out:
#              Country Region Sales Person    Date of Purchase     Total  \
# POnumbers
# 100012         India  North         John   7/25/2013 0:00:00    100000
# 100010            UK  North         John   5/20/2015 0:00:00    100000
# 10003             US  North         Bill   11/3/2014 0:00:00    120000
# 10004      Australia  North         Bill    7/5/2018 0:00:00    120000
# 100019            UK  North       Thomas    1/3/2011 0:00:00    140000
# 100017        Africa  North       Thomas   7/18/2017 0:00:00    140000
# 10006         Africa  North         John   12/7/2013 0:00:00    140000
# 100016     Singapore  North         Bill   9/22/2010 0:00:00    150000
# 100015     Australia   East         John    8/6/2018 0:00:00    160000
# 100011     Singapore   East         John   5/16/2014 0:00:00    160000
# 10000         Africa   East         Bill   7/27/2015 0:00:00    180000
# 100018       Mylasia   East         Bill   4/16/2012 0:00:00    180000
# ...

# %% [markdown]
# **Datetime in Pandas**

# %%
df['Date of Purchase']
# Out:
# POnumbers
# 100012     7/25/2013 0:00:00
# 100010     5/20/2015 0:00:00
# 10003      11/3/2014 0:00:00
# 10004       7/5/2018 0:00:00
# 100019      1/3/2011 0:00:00
# 100017     7/18/2017 0:00:00
# 10006      12/7/2013 0:00:00
# 100016     9/22/2010 0:00:00
# 100015      8/6/2018 0:00:00
# 100011     5/16/2014 0:00:00
# 10000      7/27/2015 0:00:00
# 100018     4/16/2012 0:00:00
# 10007       7/3/2014 0:00:00
# 10001      8/16/2012 0:00:00
# 10009     11/30/2011 0:00:00
# 10002      4/16/2017 0:00:00
# 100014    10/11/2015 0:00:00
# 10005     10/23/2017 0:00:00
# 100013     8/17/2012 0:00:00
# 10008      7/13/2012 0:00:00
# Name: Date of Purchase, dtype: object

# %%
df['Date of Purchase']=pd.to_datetime(df['Date of Purchase'])

# %%
df['Date of Purchase']
# Out:
# POnumbers
# 100012   2013-07-25
# 100010   2015-05-20
# 10003    2014-11-03
# 10004    2018-07-05
# 100019   2011-01-03
# 100017   2017-07-18
# 10006    2013-12-07
# 100016   2010-09-22
# 100015   2018-08-06
# 100011   2014-05-16
# 10000    2015-07-27
# 100018   2012-04-16
# 10007    2014-07-03
# 10001    2012-08-16
# 10009    2011-11-30
# 10002    2017-04-16
# 100014   2015-10-11
# 10005    2017-10-23
# 100013   2012-08-17
# 10008    2012-07-13
# Name: Date of Purchase, dtype: datetime64[ns]

# %%
df['Year']=df['Date of Purchase'].dt.year

# %%
df['Month']=df['Date of Purchase'].dt.month

# %%
df['Date']=df['Date of Purchase'].dt.day

# %%
df
# Out:
#              Country Region Sales Person Date of Purchase     Total  Quantity  \
# POnumbers
# 100012         India  North         John       2013-07-25    100000       567
# 100010            UK  North         John       2015-05-20    100000      1000
# 10003             US  North         Bill       2014-11-03    120000      3000
# 10004      Australia  North         Bill       2018-07-05    120000       567
# 100019            UK  North       Thomas       2011-01-03    140000       345
# 100017        Africa  North       Thomas       2017-07-18    140000      1000
# 10006         Africa  North         John       2013-12-07    140000        85
# 100016     Singapore  North         Bill       2010-09-22    150000        85
# 100015     Australia   East         John       2018-08-06    160000      1000
# 100011     Singapore   East         John       2014-05-16    160000       892
# 10000         Africa   East         Bill       2015-07-27    180000       123
# ...

# %% [markdown]
# **STATISTICAL FUNCTIONS IN PANDAS**

# %%
df['Total'].min()
# Out:
# 100000

# %%
df['Quantity'].max()
# Out:
# 7890

# %%
df[['Country','Quantity']].min()
# Out:
# Country     Africa
# Quantity        85
# dtype: object

# %%
df.min()
# Out:
# Country                          Africa
# Region                             East
# Sales Person                       Bill
# Date of Purchase    2010-09-22 00:00:00
# Total                            100000
# Quantity                             85
# CallsMade                            10
# Year                               2010
# Month                                 1
# Date                                  3
# dtype: object

# %%
df.max()
# Out:
# Country                              US
# Region                             West
# Sales Person                     Thomas
# Date of Purchase    2018-08-06 00:00:00
# Total                          26000000
# Quantity                           7890
# CallsMade                            60
# Year                               2018
# Month                                12
# Date                                 30
# dtype: object

# %%
df[['Country','Total','Quantity']][df['Total']==df['Total'].min()]
# Out:
#           Country   Total  Quantity
# POnumbers
# 100012      India  100000       567
# 100010         UK  100000      1000

# %%
df[['Country','Total','Quantity']][df['Total']==df['Total'].max()]
# Out:
#           Country     Total  Quantity
# POnumbers
# 10008          US  26000000      1000

# %%
df['Sellingratio']=df['Total']/df['Quantity']

# %%
df.head()
# Out:
#              Country Region Sales Person Date of Purchase   Total  Quantity  \
# POnumbers
# 100012         India  North         John       2013-07-25  100000       567
# 100010            UK  North         John       2015-05-20  100000      1000
# 10003             US  North         Bill       2014-11-03  120000      3000
# 10004      Australia  North         Bill       2018-07-05  120000       567
# 100019            UK  North       Thomas       2011-01-03  140000       345
#
#            CallsMade  Year  Month  Date  Sellingratio
# POnumbers
# 100012            10  2013      7    25    176.366843
# 100010            10  2015      5    20    100.000000
# 10003             10  2014     11     3     40.000000
# 10004             60  2018      7     5    211.640212
# 100019            10  2011      1     3    405.797101

# %%
df[['Country','Total','Quantity']][df['Sellingratio']==df['Sellingratio'].max()]
# Out:
#           Country     Total  Quantity
# POnumbers
# 10008          US  26000000      1000

# %%
df[['Country','Total','Quantity']][df['Sellingratio']==df['Sellingratio'].min()]#Person with least selling ratio
# Out:
#           Country   Total  Quantity
# POnumbers
# 10003          US  120000      3000

# %%
df['Bonus']=df['Total']*0.5

# %%
df.head()
# Out:
#              Country Region Sales Person Date of Purchase   Total  Quantity  \
# POnumbers
# 100012         India  North         John       2013-07-25  100000       567
# 100010            UK  North         John       2015-05-20  100000      1000
# 10003             US  North         Bill       2014-11-03  120000      3000
# 10004      Australia  North         Bill       2018-07-05  120000       567
# 100019            UK  North       Thomas       2011-01-03  140000       345
#
#            CallsMade  Year  Month  Date  Sellingratio    Bonus
# POnumbers
# 100012            10  2013      7    25    176.366843  50000.0
# 100010            10  2015      5    20    100.000000  50000.0
# 10003             10  2014     11     3     40.000000  60000.0
# 10004             60  2018      7     5    211.640212  60000.0
# 100019            10  2011      1     3    405.797101  70000.0

# %%
df.head()
# Out:
#              Country Region Sales Person Date of Purchase   Total  Quantity  \
# POnumbers
# 100012         India  North         John       2013-07-25  100000       567
# 100010            UK  North         John       2015-05-20  100000      1000
# 10003             US  North         Bill       2014-11-03  120000      3000
# 10004      Australia  North         Bill       2018-07-05  120000       567
# 100019            UK  North       Thomas       2011-01-03  140000       345
#
#            CallsMade  Year  Month  Date  Sellingratio    Bonus
# POnumbers
# 100012            10  2013      7    25    176.366843  50000.0
# 100010            10  2015      5    20    100.000000  50000.0
# 10003             10  2014     11     3     40.000000  60000.0
# 10004             60  2018      7     5    211.640212  60000.0
# 100019            10  2011      1     3    405.797101  70000.0

# %%
df["Country"][df["Quantity"]==df["Quantity"].min()]#country which sold least quantity
# Out:
# POnumbers
# 10006        Africa
# 100016    Singapore
# Name: Country, dtype: object

# %% [markdown]
# **DATA GROUPED REPRESENTATION**

# %%
df.groupby('Country').min()
# Out:
#           Region Sales Person Date of Purchase   Total  Quantity  CallsMade  \
# Country
# Africa      East         Bill       2013-12-07  140000        85         10
# Australia   East         Bill       2017-10-23  120000        90         10
# India       East         Bill       2012-08-16  100000        90         10
# Mylasia     East         Bill       2012-04-16  180000       444         10
# Singapore   East         Bill       2010-09-22  150000        85         10
# UK         North         Bill       2011-01-03  100000        90         10
# US         North         Bill       2011-11-30  120000        90         10
#
#            Year  Month  Date  Sellingratio    Bonus
# Country
# Africa     2013      7     7    140.000000  70000.0
# Australia  2017      7     5    160.000000  60000.0
# India      2012      4    16    176.366843  50000.0
# Mylasia    2012      4    16    126.742712  90000.0
# Singapore  2010      5     3    179.372197  75000.0
# ...

# %%
df.groupby('Country').sum()
# Out:
# <ipython-input-57-a6af796a1c93>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Country').sum()
#               Total  Quantity  CallsMade  Year  Month  Date  Sellingratio  \
# Country
# Africa       460000      1208        130  6045     26    52   3250.473458
# Australia    540000      1657        130  6053     25    34   3260.529101
# India        540000       857         80  6042     19    57   3598.589065
# Mylasia     1180000      8334         70  4024     12    33    532.148118
# Singapore    510000      1977        130  6038     21    41   2144.078080
# UK           480000      1435         80  6041     16    34   3172.463768
# US         26340000      4090         80  6037     29    46  28484.444444
#
#                 Bonus
# Country
# Africa       230000.0
# ...

# %%
df.groupby(['Country','Region']).sum()
# Out:
# <ipython-input-58-b6ecd26aa52a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Country','Region']).sum()
#                      Total  Quantity  CallsMade  Year  Month  Date  \
# Country   Region
# Africa    East      180000       123         10  2015      7    27
#           North     280000      1085        120  4030     19    25
# Australia East      160000      1000         10  2018      8     6
#           North     120000       567         60  2018      7     5
#           West      260000        90         60  2017     10    23
# India     East      200000        90         60  2012      8    16
#           North     100000       567         10  2013      7    25
#           West      240000       200         10  2017      4    16
# ...

# %%
df.groupby(['Country','Region'])['Total'].sum()
# Out:
# Country    Region
# Africa     East        180000
#            North       280000
# Australia  East        160000
#            North       120000
#            West        260000
# India      East        200000
#            North       100000
#            West        240000
# Mylasia    East        180000
#            West       1000000
# Singapore  East        360000
#            North       150000
# UK         North       240000
#            West        240000
# US         North       120000
#            West      26220000
# Name: Total, dtype: int64

# %%
df.groupby(['Quantity','Region','Country'])['Total'].sum()
# Out:
# Quantity  Region  Country
# 85        North   Africa         140000
#                   Singapore      150000
# 90        East    India          200000
#           West    Australia      260000
#                   UK             240000
#                   US             220000
# 123       East    Africa         180000
# 200       West    India          240000
# 345       North   UK             140000
# 444       East    Mylasia        180000
# 567       North   Australia      120000
#                   India          100000
# 892       East    Singapore      160000
# 1000      East    Australia      160000
#                   Singapore      200000
#           North   Africa         140000
#                   UK             100000
#           West    US           26000000
# 3000      North   US             120000
# 7890      West    Mylasia       1000000
# Name: Total, dtype: int64

# %%
df.groupby('Year')['Quantity'].sum()
# Out:
# Year
# 2010      85
# 2011     435
# 2012    9424
# 2013     652
# 2014    4892
# 2015    1213
# 2017    1290
# 2018    1567
# Name: Quantity, dtype: int64

# %%
df.groupby(df["Date of Purchase"].dt.year)["Quantity"].sum()
# Out:
# Date of Purchase
# 2010      85
# 2011     435
# 2012    9424
# 2013     652
# 2014    4892
# 2015    1213
# 2017    1290
# 2018    1567
# Name: Quantity, dtype: int64

# %%
df.groupby(df["Date of Purchase"].dt.year)["Quantity"].agg([sum,min,max])
# Out:
#                    sum  min   max
# Date of Purchase
# 2010                85   85    85
# 2011               435   90   345
# 2012              9424   90  7890
# 2013               652   85   567
# 2014              4892  892  3000
# 2015              1213   90  1000
# 2017              1290   90  1000
# 2018              1567  567  1000

# %% [markdown]
# **EXERCISE**

# %%
(df.groupby("Country")["Total"].sum()).plot(kind="pie")
# Out:
# <Axes: ylabel='Total'>

# %%
(df.groupby(["Country","Region"])["Total"].sum()).plot(kind="line")
# Out:
# <Axes: xlabel='Country,Region'>

# %%
(df.groupby(["Region","Country"])["Total"].min()).plot(kind="barh")
# Out:
# <Axes: ylabel='Region,Country'>

# %%
(df.groupby(["Region","Country"])["Total"].max()).plot(kind="barh")
# Out:
# <Axes: ylabel='Region,Country'>

# %%
#df.groupby(["Country","Region"])["Total"].sum()

# %%
#df.groupby(["Country","Region"])["Total"].min()

# %%
#df.groupby(["Country","Region"])["Total"].max()

# %% [markdown]
# **DATA VISUALIZATION**

# %%
grp_df=df.groupby(["Country"])[["Total"]].sum( )
grp_df
# Out:
#               Total
# Country
# Africa       460000
# Australia    540000
# India        540000
# Mylasia     1180000
# Singapore    510000
# UK           480000
# US         26340000

# %%
grp_df.plot.bar(title="Sales/Country",color="green")
# Out:
# <Axes: title={'center': 'Sales/Country'}, xlabel='Country'>

# %%
grp_df.plot.line( )
# Out:
# <Axes: xlabel='Country'>

# %%
grp_df.plot.pie(subplots=True)
# Out:
# array([<Axes: ylabel='Total'>], dtype=object)

# %%
grp_df.plot.scatter(x=0,y="Total")
# Out:
# <Axes: xlabel='Total', ylabel='Total'>

# %%
df.plot.bar(x="Country",y="Total")
# Out:
# <Axes: xlabel='Country'>

# %%
corr=df.corr()
corr
# Out:
# <ipython-input-77-7d5195e2bf4d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#                  Total  Quantity  CallsMade          Year         Month  \
# Total         1.000000  0.031260  -0.235009 -1.978369e-01 -3.156830e-02
# Quantity      0.031260  1.000000  -0.369531 -1.194384e-01  7.534006e-02
# CallsMade    -0.235009 -0.369531   1.000000 -4.188539e-02  3.392003e-01
# Year         -0.197837 -0.119438  -0.041885  1.000000e+00  4.610253e-15
# Month        -0.031568  0.075340   0.339200  4.610253e-15  1.000000e+00
# Date         -0.048632 -0.113582   0.190752 -1.804132e-01  1.094620e-01
# Sellingratio  0.984196 -0.070494  -0.138133 -2.137759e-01  5.202476e-02
# Bonus         1.000000  0.031260  -0.235009 -1.978369e-01 -3.156830e-02
#
#                   Date  Sellingratio     Bonus
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# **ADDING NEW DATA (MERGE,JOIN,CONCAT)**

# %%
new_df=pd.DataFrame()
new_df["Employee Name"]=df["Sales Person"].unique()
import random
exp=[1,2,4]
random.shuffle(exp)
new_df["Experience in company"]=exp
new_df["Total experience"]=new_df["Experience in company"]+random.randint(1, 10)
new_df
# Out:
#   Employee Name  Experience in company  Total experience
# 0          John                      4                10
# 1          Bill                      2                 8
# 2        Thomas                      1                 7

# %%
df.merge(new_df,left_on="Sales Person",right_on="Employee Name")
# Out:
#       Country Region Sales Person Date of Purchase     Total  Quantity  \
# 0       India  North         John       2013-07-25    100000       567
# 1          UK  North         John       2015-05-20    100000      1000
# 2      Africa  North         John       2013-12-07    140000        85
# 3   Australia   East         John       2018-08-06    160000      1000
# 4   Singapore   East         John       2014-05-16    160000       892
# 5          US   West         John       2011-11-30    220000        90
# 6     Mylasia   West         John       2012-08-17   1000000      7890
# 7          US  North         Bill       2014-11-03    120000      3000
# 8   Australia  North         Bill       2018-07-05    120000       567
# 9   Singapore  North         Bill       2010-09-22    150000        85
# 10     Africa   East         Bill       2015-07-27    180000       123
# 11    Mylasia   East         Bill       2012-04-16    180000       444
# ...

# %%
df.set_index("Sales Person",inplace=True)

# %%
new_df.set_index("Employee Name",inplace=True)

# %%
df.join(new_df)
# Out:
#           Country Region Date of Purchase     Total  Quantity  CallsMade  \
# Bill           US  North       2014-11-03    120000      3000         10
# Bill    Australia  North       2018-07-05    120000       567         60
# Bill    Singapore  North       2010-09-22    150000        85         60
# Bill       Africa   East       2015-07-27    180000       123         10
# Bill      Mylasia   East       2012-04-16    180000       444         60
# Bill        India   West       2017-04-16    240000       200         10
# Bill           UK   West       2015-10-11    240000        90         60
# John        India  North       2013-07-25    100000       567         10
# John           UK  North       2015-05-20    100000      1000         10
# John       Africa  North       2013-12-07    140000        85         60
# John    Australia   East       2018-08-06    160000      1000         10
# John    Singapore   East       2014-05-16    160000       892         60
# ...

# %%
new_df.reset_index( )
# Out:
#   Employee Name  Experience in company  Total experience
# 0          John                      4                10
# 1          Bill                      2                 8
# 2        Thomas                      1                 7

# %%
new_df1=df.copy()
new_df2=df.copy()
new_df3=df.copy()

# %%
new1=pd.concat([new_df1,new_df2])

# %%
new1
# Out:
#                 Country Region Date of Purchase     Total  Quantity  \
# Sales Person
# John              India  North       2013-07-25    100000       567
# John                 UK  North       2015-05-20    100000      1000
# Bill                 US  North       2014-11-03    120000      3000
# Bill          Australia  North       2018-07-05    120000       567
# Thomas               UK  North       2011-01-03    140000       345
# Thomas           Africa  North       2017-07-18    140000      1000
# John             Africa  North       2013-12-07    140000        85
# Bill          Singapore  North       2010-09-22    150000        85
# John          Australia   East       2018-08-06    160000      1000
# John          Singapore   East       2014-05-16    160000       892
# Bill             Africa   East       2015-07-27    180000       123
# Bill            Mylasia   East       2012-04-16    180000       444
# Thomas        Singapore   East       2014-07-03    200000      1000
# ...

# %%
new1.shape
# Out:
# (40, 11)

# %%
new1=pd.concat([new_df1,new_df2],axis=1)

# %%
new1.shape
# Out:
# (20, 22)

# %%
df.append([new_df1,new_df2,new_df3])
# Out:
# <ipython-input-105-6bf857caba64>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append([new_df1,new_df2,new_df3])
#                 Country Region Date of Purchase     Total  Quantity  \
# Sales Person
# John              India  North       2013-07-25    100000       567
# John                 UK  North       2015-05-20    100000      1000
# Bill                 US  North       2014-11-03    120000      3000
# Bill          Australia  North       2018-07-05    120000       567
# Thomas               UK  North       2011-01-03    140000       345
# ...                 ...    ...              ...       ...       ...
# Bill              India   West       2017-04-16    240000       200
# Bill                 UK   West       2015-10-11    240000        90
# Thomas        Australia   West       2017-10-23    260000        90
# John            Mylasia   West       2012-08-17   1000000      7890
# ...
